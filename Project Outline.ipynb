# %% [markdown]
# # **Title of Project**

# %% [markdown]
# -------------

# %% [markdown]
# ## **Objective**

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# ## **Import Library**

# %% [markdown]
# ## **Import Data**

# %% [markdown]
# ## **Describe Data**

# %% [markdown]
# ## **Data Visualization**

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# ## **Define Target Variable (y) and Feature Variables (X)**

# %% [markdown]
# ## **Train Test Split**

# %% [markdown]
# ## **Modeling**

# %% [markdown]
# ## **Model Evaluation**

# %% [markdown]
# ## **Prediction**

# %% [markdown]
# ## **Explaination**
